# %% [markdown]
# ## Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
prefix = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id, "kidney-ct-scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=19011f94-9642-4055-9b31-74025e90661e
# To: d:\Projects\kidney-disease-classification\research\kidney-ct-scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:19<00:00, 2.99MB/s]
# 'kidney-ct-scan-data.zip'
